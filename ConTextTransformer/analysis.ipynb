# %% [markdown]
# This file is used for testing qualitative and quantitative analysis

# %%
import matplotlib.pyplot as plt

# The given lists of values as strings
values_str1 = ['55.15', '59.89', '62.12', '63.68', '64.04', '66.31', '66.63', '67.89', '66.70', '68.40', 
               '67.83', '68.40', '68.33', '68.33', '67.73', '70.00', '70.13', '70.01', '70.08', '70.28', 
               '69.97', '70.48', '70.08', '70.18', '70.03', '70.05', '70.28', '70.16', '70.16', '70.21', 
               '70.27', '70.32', '70.06', '70.22', '70.38', '70.27', '70.22', '70.17', '70.25', '70.41', 
               '70.13', '70.27', '70.12', '70.26', '70.26', '70.00', '70.10', '70.06', '70.29', '70.15']

values_str2 = ['54.53', '59.52', '62.25', '63.58', '64.28', '65.28', '66.10', '66.39', '67.17', '68.08', 
               '66.16', '67.61', '68.13', '67.78', '68.70', '69.49', '69.43', '69.68', '70.00', '69.80', 
               '70.00', '69.91', '69.87', '69.94', '69.91', '69.99', '70.05', '69.81', '69.89', '69.96', 
               '70.12', '70.13', '70.33', '70.11', '70.11', '70.08', '70.22', '70.34', '70.18', '70.18', 
               '69.87', '70.20', '70.06', '70.10', '70.37', '70.21', '70.31', '70.32', '70.20', '70.26', 
               '70.07', '70.31', '70.21', '70.16', '69.92', '70.03', '70.28', '70.26', '70.28', '70.34', 
               '70.26', '70.15', '70.18', '70.23', '70.13', '70.12', '70.20', '70.10', '70.22', '69.95', 
               '70.07', '70.05', '70.16', '70.38', '70.17', '70.02', '70.20', '70.27', '70.27', '70.13']

# Convert the lists of strings to lists of floats
values1 = [float(value) for value in values_str1]
values2 = [float(value) for value in values_str2]

# Create a range of numbers for the x-axis
x1 = range(len(values1))
x2 = range(len(values2))

# Create the first plot with a wider figure size
plt.figure(figsize=(14, 6))
plt.plot(x1, values1, marker='o', linestyle='-', color='b')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.title('50 Epochs Accuracy')
plt.grid(True)
plt.show()

# Create the second plot with a wider figure size
plt.figure(figsize=(14, 6))
plt.plot(x2, values2, marker='o', linestyle='-', color='r')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.title('80 Epochs Accuracy')
plt.grid(True)
plt.show()
